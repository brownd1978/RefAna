# %%
import sys
extra_paths = ["/home/online1/brownd/mu2e/pyana/RefAna","/home/online1/brownd/mu2e/pyana/awkward-behaviors"]
for extra_path in extra_paths:
    print("adding path",extra_path)
    if extra_path not in sys.path:
        sys.path.append(extra_path)
print(sys.path)
# Out:
# adding path /home/online1/brownd/mu2e/pyana/RefAna
# adding path /home/online1/brownd/mu2e/pyana/awkward-behaviors
# ['/home/online1/brownd/miniconda3/envs/RefAna/lib/python313.zip', '/home/online1/brownd/miniconda3/envs/RefAna/lib/python3.13', '/home/online1/brownd/miniconda3/envs/RefAna/lib/python3.13/lib-dynload', '', '/home/online1/brownd/miniconda3/envs/RefAna/lib/python3.13/site-packages', '/home/online1/brownd/mu2e/pyana/RefAna', '/home/online1/brownd/mu2e/pyana/awkward-behaviors']

# %%
import FitReflections

# %%
reffit = FitReflections.FitReflections(reffile="/data/HD5/users/brownd/HistReflections.hdf5",cefile="/data/HD5/users/brownd/HistCe.hdf5")
# Out:
# Read  MyHist /DeltaMom/No Mat with 200 bins and 11351 entries
# Read  MyHist /DeltaMom/Target with 200 bins and 9049 entries
# Read  MyHist /TT_FrontResponse/Reflectable with 200 bins and 20058 entries
# Read  MyHist /TT_FrontResponse/All with 200 bins and 23687 entries

# %%
# reffit.TestCrystalBall(beta_0=1.0,m_0=3.00,loc_0=0,scale_0=0.5)

# %%
#reffit.TestExpGauss()

# %%
#reffit.FitExpGauss()

# %%
#reffit.FitConvExpGauss()

# %%
# reffit.FitCrystalBall()

# %%
reffit.FitConvCrystalBall()
# Out:
# All fit parameters [ 1.50482985e+03  4.51512766e-01  3.40525763e+00 -5.68447762e-01
#   2.59481907e-01]
# All fit covariance [[ 3.63027117e+02 -1.25720381e-01  5.74562392e-01 -1.73218074e-02
#    7.05890581e-03]
#  [-1.25720381e-01  5.01309476e-04 -4.79223464e-03 -9.33053783e-05
#    4.87292810e-05]
#  [ 5.74562392e-01 -4.79223464e-03  6.36389656e-02  5.61724882e-04
#   -2.44334305e-04]
#  [-1.73218074e-02 -9.33053783e-05  5.61724882e-04  4.16022516e-05
#   -2.15632344e-05]
#  [ 7.05890581e-03  4.87292810e-05 -2.44334305e-04 -2.15632344e-05
#    1.51449024e-05]]
# All fit parameters [ 1.77895320e+03  4.01290422e-01  3.87452591e+00 -4.84427322e-01
#   2.34642240e-01]
# All fit covariance [[ 4.72105703e+02 -1.49411221e-01  9.68869369e-01 -9.39429564e-03
#    3.93076786e-03]
#  [-1.49411221e-01  3.30140343e-04 -4.65162921e-03 -5.90081367e-05
#    3.08231425e-05]
#  [ 9.68869369e-01 -4.65162921e-03  9.34861457e-02  5.17910251e-04
#   -2.23376411e-04]
# ...
