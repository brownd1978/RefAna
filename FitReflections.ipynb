# %%
import sys
extra_paths = ["/home/online1/brownd/mu2e/pyana/RefAna","/home/online1/brownd/mu2e/pyana/awkward-behaviors"]
for extra_path in extra_paths:
    print("adding path",extra_path)
    if extra_path not in sys.path:
        sys.path.append(extra_path)
print(sys.path)
# Out:
# adding path /home/online1/brownd/mu2e/pyana/RefAna
# adding path /home/online1/brownd/mu2e/pyana/awkward-behaviors
# ['/home/online1/brownd/miniconda3/envs/RefAna/lib/python313.zip', '/home/online1/brownd/miniconda3/envs/RefAna/lib/python3.13', '/home/online1/brownd/miniconda3/envs/RefAna/lib/python3.13/lib-dynload', '', '/home/online1/brownd/miniconda3/envs/RefAna/lib/python3.13/site-packages', '/home/online1/brownd/mu2e/pyana/RefAna', '/home/online1/brownd/mu2e/pyana/awkward-behaviors']

# %%
import FitReflections

# %%
reffit = FitReflections.FitReflections("/data/HD5/users/brownd/HistReflections.hdf5")
# Out:
# Read  MyHist /DeltaMom/No Mat with 200 bins and 11351 entries
# Read  MyHist /DeltaMom/Target with 200 bins and 9049 entries

# %%
reffit.Test()

# %%
reffit.Fit()
# Out:
# All fit parameters [2.78510891 1.08404743 0.09129915 4.5352993 ]
# All fit covariance [[9.64819379e-04 2.92931048e-09 1.49946235e-09 8.84429523e-08]
#  [2.92931048e-09 4.02251529e-05 3.25122324e-05 8.95560677e-04]
#  [1.49946235e-09 3.25122324e-05 5.12393040e-05 7.75054629e-04]
#  [8.84429523e-08 8.95560677e-04 7.75054629e-04 2.67604976e-02]]
# /home/online1/brownd/mu2e/pyana/RefAna/FitReflections.py:20: RuntimeWarning: overflow encountered in scalar power
#   val = amp*(lamb/2)*((math.e)**((lamb/2)*(2*mu+lamb*(sigma**2)+2*x)))*comp_err_func
# /home/online1/brownd/mu2e/pyana/RefAna/FitReflections.py:20: RuntimeWarning: invalid value encountered in scalar multiply
#   val = amp*(lamb/2)*((math.e)**((lamb/2)*(2*mu+lamb*(sigma**2)+2*x)))*comp_err_func
# All fit parameters [2.51685648 1.4670292  0.18517999 1.5060791 ]
# All fit covariance [[ 5.76979681e-04 -5.81789024e-08 -3.42640529e-08 -2.51767619e-07]
#  [-5.81789024e-08  1.57799052e-04  1.39160870e-04  3.97142736e-04]
#  [-3.42640529e-08  1.39160870e-04  2.51057972e-04  3.68176269e-04]
#  [-2.51767619e-07  3.97142736e-04  3.68176269e-04  1.51357607e-03]]
