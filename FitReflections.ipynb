# %%
import sys
extra_paths = ["/home/online1/brownd/mu2e/pyana/RefAna","/home/online1/brownd/mu2e/pyana/awkward-behaviors"]
for extra_path in extra_paths:
    print("adding path",extra_path)
    if extra_path not in sys.path:
        sys.path.append(extra_path)
print(sys.path)
# Out:
# adding path /home/online1/brownd/mu2e/pyana/RefAna
# adding path /home/online1/brownd/mu2e/pyana/awkward-behaviors
# ['/home/online1/rubyknudsen/miniconda3/envs/jupyter_env/lib/python312.zip', '/home/online1/rubyknudsen/miniconda3/envs/jupyter_env/lib/python3.12', '/home/online1/rubyknudsen/miniconda3/envs/jupyter_env/lib/python3.12/lib-dynload', '', '/home/online1/rubyknudsen/miniconda3/envs/jupyter_env/lib/python3.12/site-packages', '/home/online1/brownd/mu2e/pyana/RefAna', '/home/online1/brownd/mu2e/pyana/awkward-behaviors']

# %%
import FitReflections

# %%
reffit = FitReflections.FitReflections(reffile="/data/HD5/users/rubyknudsen/HistReflections_BinnedFoilHits_073125.hdf5",
                                       cefile="/data/HD5/users/rubyknudsen/HistCe.hdf5")
# Out:
# Read  MyHist /DeltaMom/No Mat with 200 bins and 6957 entries
# Read  MyHist /DeltaMom/Target with 200 bins and 3410 entries
# Read  MyHist /DeltaMom/B12 with 200 bins and 1451 entries
# Read  MyHist /DeltaMom/B34 with 200 bins and 1313 entries
# Read  MyHist /DeltaMom/B56 with 200 bins and 617 entries
# Read  MyHist /DeltaMom/B78 with 200 bins and 412 entries
# Read  MyHist /DeltaMom/B9p with 200 bins and 91 entries
# Read  MyHist /TT_FrontResponse/Reflectable with 200 bins and 439 entries
# Read  MyHist /TT_FrontResponse/All with 200 bins and 500 entries
# Read  MyHist /DMom/B12 with 200 bins and 84 entries
# Read  MyHist /DMom/B34 with 200 bins and 156 entries
# Read  MyHist /DMom/B56 with 200 bins and 139 entries
# Read  MyHist /DMom/B78 with 200 bins and 88 entries
# Read  MyHist /DMom/B9p with 200 bins and 23 entries

# %%
reffit.TestCrystalBall()

# %%
reffit.FitConvCrystalBall()
# Out:
# All fit parameters [32.72814769  0.34254132  4.63949789 -0.49368805  0.21041764]
# All fit covariance [[ 1.65512596e+00 -2.13593401e-02  3.37576513e-01 -2.86802851e-03
#    1.14888403e-03]
#  [-2.13593401e-02  2.72449035e-03 -6.24409722e-02 -6.34016651e-04
#    3.20835578e-04]
#  [ 3.37576513e-01 -6.24409722e-02  2.01598473e+00  8.95762204e-03
#   -3.67638478e-03]
#  [-2.86802851e-03 -6.34016651e-04  8.95762204e-03  3.23307568e-04
#   -1.63439964e-04]
#  [ 1.14888403e-03  3.20835578e-04 -3.67638478e-03 -1.63439964e-04
#    1.08579742e-04]]
# All fit parameters [37.83519162  0.46403862  3.34157851 -0.49265213  0.23485226]
# All fit covariance [[ 2.31037472e+00 -3.76640314e-02  1.81204348e-01 -3.54986602e-03
#    1.21675515e-03]
#  [-3.76640314e-02  5.15282793e-03 -4.77161398e-02 -7.45699441e-04
#    3.52953014e-04]
#  [ 1.81204348e-01 -4.77161398e-02  5.95990610e-01  4.43461084e-03
#   -1.81425140e-03]
#  [-3.54986602e-03 -7.45699441e-04  4.43461084e-03  2.82318584e-04
#   -1.36026654e-04]
#  [ 1.21675515e-03  3.52953014e-04 -1.81425140e-03 -1.36026654e-04
