# %%
import sys
extra_paths = ["/home/online1/brownd/mu2e/pyana/RefAna","/home/online1/brownd/mu2e/pyana/awkward-behaviors"]
for extra_path in extra_paths:
    print("adding path",extra_path)
    if extra_path not in sys.path:
        sys.path.append(extra_path)
print(sys.path)
# Out:
# adding path /home/online1/brownd/mu2e/pyana/RefAna
# adding path /home/online1/brownd/mu2e/pyana/awkward-behaviors
# ['/home/online1/brownd/miniconda3/envs/RefAna/lib/python313.zip', '/home/online1/brownd/miniconda3/envs/RefAna/lib/python3.13', '/home/online1/brownd/miniconda3/envs/RefAna/lib/python3.13/lib-dynload', '', '/home/online1/brownd/miniconda3/envs/RefAna/lib/python3.13/site-packages', '/home/online1/brownd/mu2e/pyana/RefAna', '/home/online1/brownd/mu2e/pyana/awkward-behaviors']

# %%
import FitReflections

# %%
reffit = FitReflections.FitReflections("/data/HD5/users/brownd/HistReflections.hdf5")
# Out:
# Read  MyHist /DeltaMom/No Mat with 200 bins and 11351 entries
# Read  MyHist /DeltaMom/Target with 200 bins and 9049 entries

# %%
reffit.TestCrystalBall(beta_0=1.0,m_0=3.00,loc_0=0,scale_0=0.5)

# %%
reffit.TestExpGauss()

# %%
reffit.FitExpGauss()
# Out:
# All fit parameters [ 7.90647063e+02 -2.32482827e-01  1.52855055e-01  2.85649176e+00]
# All fit covariance [[2.44769551e+02 1.03706750e-06 1.91550338e-07 2.40381172e-05]
#  [1.03706750e-06 7.06439463e-05 3.41061510e-05 5.98478852e-04]
#  [1.91550338e-07 3.41061510e-05 4.59119112e-05 3.43810547e-04]
#  [2.40381172e-05 5.98478852e-04 3.43810547e-04 9.54462447e-03]]
# All fit parameters [6.47412736e+02 7.51174969e-01 3.50640556e-01 9.31713706e-01]
# All fit covariance [[ 1.03879255e+02 -2.82387985e-04 -1.26822534e-04 -6.47379437e-04]
#  [-2.82387985e-04  2.71196026e-04  1.32656594e-04  2.46556885e-04]
#  [-1.26822534e-04  1.32656594e-04  1.76843298e-04  1.37793026e-04]
#  [-6.47379437e-04  2.46556885e-04  1.37793026e-04  5.04567736e-04]]
# /home/online1/brownd/mu2e/pyana/RefAna/FitReflections.py:56: RuntimeWarning: overflow encountered in power
#   val = amp*(lamb/2)*((math.e)**((lamb/2)*(2*mu+lamb*(sigma**2)+2*x)))*comp_err_func
# /home/online1/brownd/mu2e/pyana/RefAna/FitReflections.py:56: RuntimeWarning: invalid value encountered in multiply
#   val = amp*(lamb/2)*((math.e)**((lamb/2)*(2*mu+lamb*(sigma**2)+2*x)))*comp_err_func

# %%
reffit.FitConvExpGauss()
# Out:
# /home/online1/brownd/mu2e/pyana/RefAna/FitReflections.py:56: RuntimeWarning: overflow encountered in scalar power
#   val = amp*(lamb/2)*((math.e)**((lamb/2)*(2*mu+lamb*(sigma**2)+2*x)))*comp_err_func
# /home/online1/brownd/mu2e/pyana/RefAna/FitReflections.py:56: RuntimeWarning: invalid value encountered in scalar multiply
#   val = amp*(lamb/2)*((math.e)**((lamb/2)*(2*mu+lamb*(sigma**2)+2*x)))*comp_err_func
# All fit parameters [ 7.75851019e+04 -1.68519440e-01  9.13917255e-02  4.53486215e+00]
# All fit covariance [[2.98757988e+06 1.50258539e-04 8.13762044e-05 4.40777611e-03]
#  [1.50258539e-04 4.02245005e-05 3.25186882e-05 8.95166304e-04]
#  [8.13762044e-05 3.25186882e-05 5.12388722e-05 7.74902093e-04]
