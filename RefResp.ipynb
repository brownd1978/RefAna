# %%
import RefResp

# %%
onefile = ["/data/HD5/users/brownd/61803286/nts.brownd.TAReflect.CRYAllOffSpill.001202_00000010.root"]
twofile = ["/data/HD5/users/brownd/61803286/nts.brownd.TAReflect.CRYAllOffSpill.001202_00000518.root" ]
allfiles = [
"/data/HD5/users/brownd/61803286/nts.brownd.TAReflect.CRYAllOffSpill.001202_00000010.root",
"/data/HD5/users/brownd/61803286/nts.brownd.TAReflect.CRYAllOffSpill.001202_00000518.root",
"/data/HD5/users/brownd/61803286/nts.brownd.TAReflect.CRYAllOffSpill.001202_00001032.root",
"/data/HD5/users/brownd/61803286/nts.brownd.TAReflect.CRYAllOffSpill.001202_00001547.root",
"/data/HD5/users/brownd/61803286/nts.brownd.TAReflect.CRYAllOffSpill.001202_00002057.root",
"/data/HD5/users/brownd/61803286/nts.brownd.TAReflect.CRYAllOffSpill.001202_00002561.root",
"/data/HD5/users/brownd/61803286/nts.brownd.TAReflect.CRYAllOffSpill.001202_00003067.root",
"/data/HD5/users/brownd/61803286/nts.brownd.TAReflect.CRYAllOffSpill.001202_00003570.root",
"/data/HD5/users/brownd/61803286/nts.brownd.TAReflect.CRYAllOffSpill.001202_00004074.root",
"/data/HD5/users/brownd/61803286/nts.brownd.TAReflect.CRYAllOffSpill.001202_00004577.root",
"/data/HD5/users/brownd/61803286/nts.brownd.TAReflect.CRYAllOffSpill.001202_00005081.root",
"/data/HD5/users/brownd/61803286/nts.brownd.TAReflect.CRYAllOffSpill.001202_00005616.root",
"/data/HD5/users/brownd/61803286/nts.brownd.TAReflect.CRYAllOffSpill.001202_00006156.root",
"/data/HD5/users/brownd/61803286/nts.brownd.TAReflect.CRYAllOffSpill.001202_00006706.root",
"/data/HD5/users/brownd/61803286/nts.brownd.TAReflect.CRYAllOffSpill.001202_00007246.root",
"/data/HD5/users/brownd/61803286/nts.brownd.TAReflect.CRYAllOffSpill.001202_00007764.root",
"/data/HD5/users/brownd/61803286/nts.brownd.TAReflect.CRYAllOffSpill.001202_00008324.root",
"/data/HD5/users/brownd/61803286/nts.brownd.TAReflect.CRYAllOffSpill.001202_00008894.root",
"/data/HD5/users/brownd/61803286/nts.brownd.TAReflect.CRYAllOffSpill.001202_00009535.root",
"/data/HD5/users/brownd/61803286/nts.brownd.TAReflect.CRYAllOffSpill.001202_00013483.root"
]
offfiles = onefile

# %%
emrange = [80,130]
rem = RefResp.RefResp(emrange,11,13)
rem.Print()
# Out:
# In RefResp constructor
# ReflectionResponse object, nhits = 20

# %%
rem.Loop(offfiles,"TARe/ntuple")
# Out:
# Processing batch  0
# From 1072 total reflections found 698 with good quality reco, 572 confirmed $e^-$ and 190 in momentum range [80, 130]
# For All |Delta T| <  5.0  efficiency =  0.9580536912751678  purity =  0.9982517482517482
# /home/online1/brownd/mu2e/pyana/RefAna/RefResp.py:18: RuntimeWarning: overflow encountered in power
#   val = amp*(lamb/2)*((math.e)**((lamb/2)*(2*mu+lamb*(sigma**2)+2*x)))*comp_err_func
# /home/online1/brownd/mu2e/pyana/RefAna/RefResp.py:18: RuntimeWarning: invalid value encountered in multiply
#   val = amp*(lamb/2)*((math.e)**((lamb/2)*(2*mu+lamb*(sigma**2)+2*x)))*comp_err_func
# /home/online1/brownd/mu2e/pyana/RefAna/RefResp.py:18: RuntimeWarning: overflow encountered in multiply
#   val = amp*(lamb/2)*((math.e)**((lamb/2)*(2*mu+lamb*(sigma**2)+2*x)))*comp_err_func
# Trk fit parameters [9.90176853 1.48437259 0.32251122 2.07248202]
# Trk fit covariance [[ 2.60318075e-01 -2.22515600e-03 -1.97282892e-04 -2.05942690e-02]
#  [-2.22515600e-03  2.26848774e-03  1.11626221e-03  1.26650915e-02]
#  [-1.97282892e-04  1.11626221e-03  1.66509386e-03  8.29529647e-03]
#  [-2.05942690e-02  1.26650915e-02  8.29529647e-03  9.97753788e-02]]
# MC Fit parameters [9.84656491 1.36846974 0.25712597 1.41434718]
# MC Fit covariance [[ 0.24074158 -0.00173831  0.00056769 -0.00803255]
#  [-0.00173831  0.00156472  0.00066335  0.00432151]
#  [ 0.00056769  0.00066335  0.00126403  0.00270539]
#  [-0.00803255  0.00432151  0.00270539  0.02203452]]

# %%
eprange = [80,130]
rep = RefResp.RefResp(eprange,-11,-13)
rep.Print()
# Out:
# In RefResp constructor
# ReflectionResponse object, nhits = 20

# %%
rep.Loop(offfiles,"TARe/ntuple")
# Out:
# Processing batch  0
# From 1072 total reflections found 182 with good quality reco, 94 confirmed $e^+$ and 36 in momentum range [80, 130]
# For All |Delta T| <  5.0  efficiency =  0.9591836734693877  purity =  1.0
# Trk fit parameters [1.89288255 1.49143705 0.00752245 1.77378432]
# Trk fit covariance [[ 1.08740913e+10 -3.15480910e+09 -6.19500129e+09 -2.40411939e+03]
#  [-3.15480910e+09  9.15278363e+08  1.79730388e+09  6.97484091e+02]
#  [-6.19500129e+09  1.79730388e+09  3.52931017e+09  1.36962775e+03]
#  [-2.40411939e+03  6.97484091e+02  1.36962775e+03  4.30111818e-02]]
# MC Fit parameters [1.69356503 1.41289205 0.01106709 1.22823578]
# MC Fit covariance [[ 3.86047928e+07 -1.19579850e+07 -5.12316255e+08  8.22698276e+01]
#  [-1.19579850e+07  3.70403243e+06  1.58691956e+08 -2.54889934e+01]
#  [-5.12316255e+08  1.58691956e+08  6.79884352e+09 -1.09203496e+03]
#  [ 8.22698276e+01 -2.54889934e+01 -1.09203496e+03  3.50224100e-02]]

# %%
mumrange = [100,150]
rmum = RefResp.RefResp(mumrange,13,11)
rmum.Print()
# Out:
# In RefResp constructor
# ReflectionResponse object, nhits = 20

# %%
rmum.Loop(offfiles,"TARmu/ntuple")
# Out:
# Processing batch  0
# From 1256 total reflections found 539 with good quality reco, 484 confirmed $\mu^-$ and 247 in momentum range [100, 150]
# For All |Delta T| <  5.0  efficiency =  0.9343629343629344  purity =  1.0
# Trk fit parameters [14.20908142  2.33143038  0.37187431  0.56464442]
# Trk fit covariance [[ 0.5268676  -0.00713982 -0.00207587 -0.01214818]
#  [-0.00713982  0.00370647  0.00195286  0.00187616]
#  [-0.00207587  0.00195286  0.00417538  0.0013164 ]
#  [-0.01214818  0.00187616  0.0013164   0.00265197]]
# MC Fit parameters [14.66266845  2.44135673  0.49169899  0.58921576]
# MC Fit covariance [[ 0.47357932 -0.00880141 -0.00168616 -0.01134928]
#  [-0.00880141  0.00504181  0.0026569   0.00257475]
#  [-0.00168616  0.0026569   0.00486907  0.00181553]
#  [-0.01134928  0.00257475  0.00181553  0.00292414]]

# %%
muprange = [100,150]
rmup = RefResp.RefResp(mumrange,-13,-11)
rmup.Print()
# Out:
# In RefResp constructor
# ReflectionResponse object, nhits = 20

# %%
rmup.Loop(offfiles,"TARmu/ntuple")
# Out:
# Processing batch  0
# From 1256 total reflections found 561 with good quality reco, 524 confirmed $\mu^+$ and 265 in momentum range [100, 150]
# For All |Delta T| <  5.0  efficiency =  0.9441441441441442  purity =  1.0
# Trk fit parameters [15.26865673  2.94436651  0.75303714  1.05025506]
# Trk fit covariance [[ 0.46898892 -0.01037334 -0.00209244 -0.02137121]
#  [-0.01037334  0.00972396  0.00502402  0.01360505]
#  [-0.00209244  0.00502402  0.00626187  0.00865727]
#  [-0.02137121  0.01360505  0.00865727  0.02549219]]
# MC Fit parameters [15.90586847  2.78795542  0.80476034  0.9188342 ]
# MC Fit covariance [[ 0.45940577 -0.01245698 -0.00273141 -0.02032784]
#  [-0.01245698  0.01005547  0.00505874  0.01085891]
#  [-0.00273141  0.00505874  0.00596628  0.0066028 ]
#  [-0.02032784  0.01085891  0.0066028   0.01607002]]
