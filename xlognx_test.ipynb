# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.special import erfcinv
from scipy.special import erfc

# %%
erfcinv(0.5)
erfc(0.0)
# Out:
# np.float64(1.0)

# %%
y = np.linspace(0.0, 2.0, num=1000001)
erfcinv(y)
# Out:
# array([        inf,  3.36117856,  3.26073974, ..., -3.26073974,
#        -3.36117856,        -inf], shape=(1000001,))

# %%
y = np.linspace(0, 2, 200)
fig, ax = plt.subplots()
ax.plot(y, erfcinv(y))
ax.grid(True)
ax.set_xlabel('y')
ax.set_title('erfcinv(y)')
plt.show()

# %%
mu, sigma = 1.77, 0.8 # mean and standard deviation
s = np.random.lognormal(mu, sigma, 100000)
#print(s[0:10])

# %%
count, bins, ignored = plt.hist(s, 200, density=True, align='mid',range=(0,250))
x = np.linspace(min(bins), max(bins), 10000)
pdf = (np.exp(-(np.log(x) - mu)**2 / (2 * sigma**2))
       / (x * sigma * np.sqrt(2 * np.pi)))
plt.plot(x, pdf, linewidth=2, color='r')
plt.axis('tight')
plt.show()
# Out:
# /tmp/ipykernel_1785983/1337803724.py:3: RuntimeWarning: divide by zero encountered in log
#   pdf = (np.exp(-(np.log(x) - mu)**2 / (2 * sigma**2))
# /tmp/ipykernel_1785983/1337803724.py:3: RuntimeWarning: invalid value encountered in divide
#   pdf = (np.exp(-(np.log(x) - mu)**2 / (2 * sigma**2))

# %%
q = np.random.random(size=100000)
offset = mu + sigma**2
scale = -np.sqrt(2)*sigma
y = np.exp(offset + scale*erfcinv(2*q))
#print(y)

# %%
count, bins, ignored = plt.hist(y, 200, density=True, align='mid',range=(0,250))
#plt.show()
#print(bins)
x = np.linspace(0.0, 250, 10000)
pdf = (np.exp(-(np.log(x) - mu)**2 / (2 * sigma**2))
       / (sigma * np.sqrt(2 * np.pi)*np.exp(mu + 0.5*sigma**2)))
plt.plot(x, pdf, linewidth=2, color='r')
plt.axis('tight')
plt.show()
# Out:
# /tmp/ipykernel_1785983/3275870232.py:5: RuntimeWarning: divide by zero encountered in log
#   pdf = (np.exp(-(np.log(x) - mu)**2 / (2 * sigma**2))
