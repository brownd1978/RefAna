# %%
# %run Debug.py
# Out:
# Processing batch  0
# From  1065  total reflections 686  good quality reco with  575  confirmed eminus and  142 signal-like reflections for resolution
# For |Delta T| <  5.0  efficiency =  0.9599332220367279  purity =  1.0
# /home/online1/brownd/mu2e/pyana/RefAna/Debug.py:16: RuntimeWarning: overflow encountered in power
#   val = amp*(lamb/2)*((math.e)**((lamb/2)*(2*mu+lamb*(sigma**2)+2*x)))*comp_err_func
# /home/online1/brownd/mu2e/pyana/RefAna/Debug.py:16: RuntimeWarning: invalid value encountered in multiply
#   val = amp*(lamb/2)*((math.e)**((lamb/2)*(2*mu+lamb*(sigma**2)+2*x)))*comp_err_func
# Trk fit parameters [7.95268623 1.53473163 0.39859567 1.5859163 ]
# Trk fit covariance [[ 0.15824289 -0.0029654   0.00027114 -0.01589124]
#  [-0.0029654   0.00357057  0.00181763  0.01166586]
#  [ 0.00027114  0.00181763  0.00240861  0.00762535]
#  [-0.01589124  0.01166586  0.00762535  0.0543824 ]]
# MC Fit parameters [8.57063362 1.41033182 0.30077647 1.64986279]
# ...
