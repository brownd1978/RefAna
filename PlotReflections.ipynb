# %%
import sys
extra_paths = ["/home/online1/brownd/mu2e/pyana/RefAna","/home/online1/brownd/mu2e/pyana/awkward-behaviors"]
for extra_path in extra_paths:
    print("adding path",extra_path)
    if extra_path not in sys.path:
        sys.path.append(extra_path)
print(sys.path)
# Out:
# adding path /home/online1/brownd/mu2e/pyana/RefAna
# adding path /home/online1/brownd/mu2e/pyana/awkward-behaviors
# ['', '/cvmfs/mu2e.opensciencegrid.org/env/ana/2.7.0/lib/python3.12/site-packages', '/cvmfs/mu2e.opensciencegrid.org/spackages/241207/spack/opt/spack/linux-almalinux9-x86_64_v2/gcc-11.5.0/muse-4.17.0-di7thnqtj43r5ojxh6gum5pqg42mwmn2/python', '/cvmfs/mu2e.opensciencegrid.org/env/ana/2.7.0/lib/python312.zip', '/cvmfs/mu2e.opensciencegrid.org/env/ana/2.7.0/lib/python3.12', '/cvmfs/mu2e.opensciencegrid.org/env/ana/2.7.0/lib/python3.12/lib-dynload', '/home/online1/brownd/mu2e/pyana/RefAna', '/home/online1/brownd/mu2e/pyana/awkward-behaviors']

# %%
import PlotReflections

# %%
#refplote = PlotReflections.PlotReflections("/data/HD5/users/brownd/HistRefSelPerfe.hd5")
refplote = PlotReflections.PlotReflections("/data/HD5/users/brownd/HistRefSele.hd5")
refplotmu = PlotReflections.PlotReflections("/data/HD5/users/brownd/HistRefSelmu.hd5")
# Out:
# Read  MyHist /HUpTQ/Up TrkQual with 100 bins and 803 entries
# Read  MyHist /HDnTQ/Down TrkQual with 100 bins and 803 entries
# Read  MyHist /HUpFitCon/Up FitCon with 100 bins and 803 entries
# Read  MyHist /HDnFitCon/Down FitCon with 100 bins and 803 entries
# Read  MyHist /HUpNHits/Up NActive with 100 bins and 803 entries
# Read  MyHist /HDnNHits/Down NActive with 100 bins and 803 entries
# Read  MyHist /NInter/All ST with 31 bins and 8756 entries
# Read  MyHist /NInter/All IPA with 31 bins and 8454 entries
# Read  MyHist /NInter/Target ST with 31 bins and 803 entries
# Read  MyHist /NInter/Target IPA with 31 bins and 803 entries
# Read  MyHist /DnMom/All with 100 bins and 7654 entries
# Read  MyHist /DnMom/$N_{ST}$>0 with 100 bins and 803 entries
# Read  MyHist /DnMom/No Material with 100 bins and 1245 entries
# Read  MyHist /UpMom/All with 100 bins and 7653 entries
# Read  MyHist /UpMom/$N_{ST}$>0 with 100 bins and 803 entries
# Read  MyHist /UpMom/No Material with 100 bins and 1245 entries
# Read  MyHist /DnDeltaMom/All with 200 bins and 7658 entries
# Read  MyHist /DnDeltaMom/$N_{ST}$>0 with 200 bins and 803 entries
# Read  MyHist /DnDeltaMom/No Material with 200 bins and 1245 entries
# Read  MyHist /UpDeltaMom/All with 200 bins and 7661 entries
# Read  MyHist /UpDeltaMom/$N_{ST}$>0 with 200 bins and 803 entries
# Read  MyHist /UpDeltaMom/No Material with 200 bins and 1245 entries
# Read  MyHist /DeltaTime/Upstream with 100 bins and 7662 entries
# Read  MyHist /DeltaTime/Downstream with 100 bins and 7662 entries
# Read  MyHist /HUpTQ/Up TrkQual with 100 bins and 1660 entries
# Read  MyHist /HDnTQ/Down TrkQual with 100 bins and 1660 entries
# Read  MyHist /HUpFitCon/Up FitCon with 100 bins and 1660 entries
# Read  MyHist /HDnFitCon/Down FitCon with 100 bins and 1660 entries
# Read  MyHist /HUpNHits/Up NActive with 100 bins and 1660 entries
# Read  MyHist /HDnNHits/Down NActive with 100 bins and 1660 entries
# Read  MyHist /NInter/All ST with 31 bins and 11540 entries
# Read  MyHist /NInter/All IPA with 31 bins and 11523 entries
# Read  MyHist /NInter/Target ST with 31 bins and 1660 entries
# Read  MyHist /NInter/Target IPA with 31 bins and 1660 entries
# Read  MyHist /DnMom/All with 100 bins and 9754 entries
# Read  MyHist /DnMom/$N_{ST}$>0 with 100 bins and 1660 entries
# Read  MyHist /DnMom/No Material with 100 bins and 1197 entries
# Read  MyHist /UpMom/All with 100 bins and 9750 entries
# Read  MyHist /UpMom/$N_{ST}$>0 with 100 bins and 1660 entries
# Read  MyHist /UpMom/No Material with 100 bins and 1193 entries
# Read  MyHist /DnDeltaMom/All with 200 bins and 9745 entries
# Read  MyHist /DnDeltaMom/$N_{ST}$>0 with 200 bins and 1651 entries
# Read  MyHist /DnDeltaMom/No Material with 200 bins and 1207 entries
# Read  MyHist /UpDeltaMom/All with 200 bins and 9752 entries
# Read  MyHist /UpDeltaMom/$N_{ST}$>0 with 200 bins and 1651 entries
# Read  MyHist /UpDeltaMom/No Material with 200 bins and 1207 entries
# Read  MyHist /DeltaTime/Upstream with 100 bins and 9764 entries
# Read  MyHist /DeltaTime/Downstream with 100 bins and 9764 entries

# %%
refplote.PlotIntersections()

# %%
refplote.PlotMomentum()

# %%
refplote.PlotDeltaMomentum()

# %%
refplote.PlotQuality()

# %%
refplote.PlotTime()

# %%
refplotmu.PlotIntersections()

# %%
refplotmu.PlotMomentum()

# %%
refplotmu.PlotQuality()

# %%
refplotmu.PlotTime()
