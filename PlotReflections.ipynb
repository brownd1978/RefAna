# %%
import sys
extra_paths = ["/home/online1/brownd/mu2e/pyana/RefAna","/home/online1/brownd/mu2e/pyana/awkward-behaviors"]
for extra_path in extra_paths:
    print("adding path",extra_path)
    if extra_path not in sys.path:
        sys.path.append(extra_path)
print(sys.path)
# Out:
# adding path /home/online1/brownd/mu2e/pyana/RefAna
# adding path /home/online1/brownd/mu2e/pyana/awkward-behaviors
# ['/home/online1/brownd/miniconda3/envs/RefAna/lib/python313.zip', '/home/online1/brownd/miniconda3/envs/RefAna/lib/python3.13', '/home/online1/brownd/miniconda3/envs/RefAna/lib/python3.13/lib-dynload', '', '/home/online1/brownd/miniconda3/envs/RefAna/lib/python3.13/site-packages', '/home/online1/brownd/mu2e/pyana/RefAna', '/home/online1/brownd/mu2e/pyana/awkward-behaviors']

# %%
import PlotReflections

# %%
refplot = PlotReflections.PlotReflections("/data/HD5/users/brownd/HistReflections.hdf5")
# Out:
# Read  MyHist /NInter/All ST with 20 bins and 111445 entries
# Read  MyHist /NInter/All IPA with 20 bins and 111445 entries
# Read  MyHist /NInter/Target ST with 20 bins and 9113 entries
# Read  MyHist /NInter/Target IPA with 20 bins and 9113 entries
# Read  MyHist /DnMom/All with 100 bins and 93501 entries
# Read  MyHist /DnMom/Target with 100 bins and 9113 entries
# Read  MyHist /DnMom/No Target with 100 bins and 14418 entries
# Read  MyHist /DnMom/No IPA with 100 bins and 11302 entries
# Read  MyHist /DnMom/No Mat with 100 bins and 11301 entries
# Read  MyHist /UpMom/All with 100 bins and 93549 entries
# Read  MyHist /UpMom/Target with 100 bins and 9113 entries
# Read  MyHist /UpMom/No Target with 100 bins and 14418 entries
# Read  MyHist /UpMom/No IPA with 100 bins and 11301 entries
# Read  MyHist /UpMom/No Mat with 100 bins and 11300 entries
# Read  MyHist /DeltaMom/All with 200 bins and 93333 entries
# Read  MyHist /DeltaMom/Target with 200 bins and 9049 entries
# Read  MyHist /DeltaMom/No Target with 200 bins and 14400 entries
# Read  MyHist /DeltaMom/No IPA with 200 bins and 11352 entries
# Read  MyHist /DeltaMom/No Mat with 200 bins and 11351 entries

# %%
refplot.PlotIntersections()

# %%
refplot.PlotMomentum()
