# %%
import sys
extra_paths = ["/home/online1/brownd/mu2e/pyana/RefAna","/home/online1/brownd/mu2e/pyana/awkward-behaviors"]
for extra_path in extra_paths:
    print("adding path",extra_path)
    if extra_path not in sys.path:
        sys.path.append(extra_path)
print(sys.path)
# Out:
# adding path /home/online1/brownd/mu2e/pyana/RefAna
# adding path /home/online1/brownd/mu2e/pyana/awkward-behaviors
# ['/home/online1/brownd/mu2e/pyana/RefAna', '/home/online1/brownd/mu2e/pyana/awkward-behaviors', '/home/online1/brownd/miniconda3/envs/RefAna/lib/python313.zip', '/home/online1/brownd/miniconda3/envs/RefAna/lib/python3.13', '/home/online1/brownd/miniconda3/envs/RefAna/lib/python3.13/lib-dynload', '', '/home/online1/brownd/miniconda3/envs/RefAna/lib/python3.13/site-packages']

# %%
import CeAna
import SurfaceIds

# %%
#file = ["/data/HD6/users/brownd/ntp.mu2e.CeEndpointOnSpillTriggered.MDC2020aq_best_v1_3_debug_mc.root"]
#file = ["/data/HD6/users/brownd/ntp.mu2e.CeEndpointOnSpillTriggered.MDC2020aq_best_v1_3_spack.root" ]
file=["/data/HD6/users/brownd/ntp.mu2e.CeEndpointOnSpillTriggered.MDC2020aq_best_v1_3_spack_nofilter.root"]
#file=["/data/HD6/users/brownd/ntp.mu2e.CeEndpointOnSpillTriggered.MDC2020aq_best_v1_3_test.root"]

# %%
sids =[0,1,2]
momrange=[80,110]

# %%
ce = CeAna.CeAna(momrange,20,0.0,sids)

# %%
ce.Loop(file)
# Out:
# ['ntuple;13', 'ntuple;12', 'version;1']
# [{event: 4, run: 1210, subrun: 0, nprotons: 0, pbtime: -207, ...}, ..., {...}] <class 'awkward.highlevel.Array'>
# Processing batch  0
# [{event: 984, run: 1210, subrun: 5, nprotons: 0, pbtime: -219, ...}, ..., {...}] <class 'awkward.highlevel.Array'>
# Processing batch  1
# [{event: 1409, run: 1210, subrun: 10, nprotons: 0, pbtime: -207, ...}, ...] <class 'awkward.highlevel.Array'>
# Processing batch  2
# [{event: 2168, run: 1210, subrun: 15, nprotons: 0, pbtime: -222, ...}, ...] <class 'awkward.highlevel.Array'>
# Processing batch  3
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 ce.Loop(file)
#
# File ~/mu2e/pyana/RefAna/CeAna.py:228, in CeAna.Loop(self, files)
#     226     p0 = np.array([amp_0, mu_0, sigma_0, lamb_0]) # initial parameters
#     227 # fit, returing optimum parameters and covariance
# --> 228     popt, pcov = curve_fit(fxn_expGauss, momRespBinMid, momRespHist[0], p0, sigma=momRespErrors)
#     229     print("For SID=",self.SIDs[isid],"Trk fit parameters",popt)
#     230     print("Trk fit covariance",pcov)
#
# File ~/miniconda3/envs/RefAna/lib/python3.13/site-packages/scipy/optimize/_minpack_py.py:1014, in curve_fit(f, xdata, ydata, p0, sigma, absolute_sigma, check_finite, bounds, method, jac, full_output, nan_policy, **kwargs)
#    1011 if ydata.size != 1 and n > ydata.size:
#    1012     raise TypeError(f"The number of func parameters={n} must not"
#    1013                     f" exceed the number of data points={ydata.size}")
# -> 1014 res = leastsq(func, p0, Dfun=jac, full_output=1, **kwargs)
#    1015 popt, pcov, infodict, errmsg, ier = res
#    1016 ysize = len(infodict['fvec'])
#
# File ~/miniconda3/envs/RefAna/lib/python3.13/site-packages/scipy/optimize/_minpack_py.py:425, in leastsq(func, x0, args, Dfun, full_output, col_deriv, ftol, xtol, gtol, maxfev, epsfcn, factor, diag)
#     423 if not isinstance(args, tuple):
#     424     args = (args,)
# --> 425 shape, dtype = _check_func('leastsq', 'func', func, x0, args, n)
#     426 m = shape[0]
#     428 if n > m:
#
# File ~/miniconda3/envs/RefAna/lib/python3.13/site-packages/scipy/optimize/_minpack_py.py:23, in _check_func(checker, argname, thefunc, x0, args, numinputs, output_shape)
#      21 def _check_func(checker, argname, thefunc, x0, args, numinputs,
#      22                 output_shape=None):
# ---> 23     res = atleast_1d(thefunc(*((x0[:numinputs],) + args)))
#      24     if (output_shape is not None) and (shape(res) != output_shape):
#      25         if (output_shape[0] != 1):
#
# File ~/miniconda3/envs/RefAna/lib/python3.13/site-packages/scipy/optimize/_minpack_py.py:522, in _lightweight_memoizer.<locals>._memoized_func(params)
#     519 elif _memoized_func.last_params is not None:
#     520     _memoized_func.skip_lookup = True
# --> 522 val = f(params)
#     524 if _memoized_func.last_params is None:
#     525     _memoized_func.last_params = np.copy(params)
#
# File ~/miniconda3/envs/RefAna/lib/python3.13/site-packages/scipy/optimize/_minpack_py.py:542, in _wrap_func.<locals>.func_wrapped(params)
#     541 def func_wrapped(params):
# --> 542     return transform * (func(xdata, *params) - ydata)
#
# TypeError: unsupported operand type(s) for -: 'NoneType' and 'float'
